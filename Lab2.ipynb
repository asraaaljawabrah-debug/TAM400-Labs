# %% [markdown]
# <a href="https://colab.research.google.com/github/asraaaljawabrah-debug/TAM400-Labs/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello TAM400")
# Out:
# Hello TAM400
